# %% [markdown]
# # <font color=red>Class 09 : Encoding Assignment</font>

# %% [markdown]
# ## Question:
# ## Preprocess the housing dataset by encoding all categorical variables using appropriate techniques. Ensure the final dataset is fully numeric and ready for machine learning analysis. y = SalePrice.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('house.xlsx')

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
x =  df.drop('Id', axis=1)

# %%
y = df.SalePrice

# %% [markdown]
# # <font color=red>checking null values</font>

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # Measure of Central Tendency

# %%
df.LotFrontage.mean()
# Out:
# 70.04995836802665

# %%
df.LotFrontage.median()
# Out:
# 69.0

# %%
import seaborn as sns
sns.histplot(df.LotFrontage)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='Count'>

# %%
mean =df.LotFrontage.mean()
df.LotFrontage = df.LotFrontage.fillna(mean)
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %% [markdown]
# ## Copy Data

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()

# %% [markdown]
# # <font color=red>Sklearn Preprocessing</font>
# ## Some common encoding techniques in machine learning:
# 1. Label Encoding
# 2. One-Hot Encoding
# 3. Binary Encoding
# 4. Ordinal Encoding
# 5. Frequency Encoding
# 7. Mean Encoding
# 8. Text Embedding

# %% [markdown]
# # 1. Label Encoding

# %%
df1.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.nunique().to_frame(name='Unique Values').join(df.dtypes.to_frame(name='Data Type'))
# Out:
#                Unique Values Data Type
# Id                      1460     int64
# MSSubClass                15     int64
# MSZoning                   5    object
# LotFrontage              111   float64
# LotArea                 1073     int64
# ...                      ...       ...
# MoSold                    12     int64
# YrSold                     5     int64
# SaleType                   9    object
# SaleCondition              6    object
# SalePrice                663     int64
#
# [81 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1.MSZoning = le.fit_transform(df1['MSZoning'])
df1.MSZoning.unique()
# Out:
# array([3, 4, 0, 1, 2])

# %% [markdown]
# # 2. One-Hot Encoding

# %%
df2.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.get_dummies(df2['SaleCondition']).head()
dummy = pd.get_dummies(df2['SaleCondition'], drop_first=True).head()
dummy.head(3)
# Out:
#    AdjLand  Alloca  Family  Normal  Partial
# 0    False   False   False    True    False
# 1    False   False   False    True    False
# 2    False   False   False    True    False

# %%
df2.drop('SaleCondition', axis=1, inplace=True)
df2.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SalePrice
# 0       0      2    2008        WD     208500
# 1       0      5    2007        WD     181500
# 2       0      9    2008        WD     223500
#
# [3 rows x 80 columns]

# %%
new_df2 = pd.concat([df2, dummy], axis=1)
new_df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscVal MoSold YrSold SaleType SalePrice AdjLand  \
# 0         Lvl    AllPub  ...       0      2   2008       WD    208500   False
# 1         Lvl    AllPub  ...       0      5   2007       WD    181500   False
# 2         Lvl    AllPub  ...       0      9   2008       WD    223500   False
# 3         Lvl    AllPub  ...       0      2   2006       WD    140000   False
# 4         Lvl    AllPub  ...       0     12   2008       WD    250000   False
#
#   Alloca  Family  Normal  Partial
# 0  False   False    True    False
# ...

# %% [markdown]
# # 3. Binary Encoding

# %%
df3.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
import category_encoders as ce
be = ce.BinaryEncoder(cols=['SaleType'])
be
# Out:
# BinaryEncoder(cols=['SaleType'])

# %%
df3_binary_encoded = be.fit_transform(df3)
df3_binary_encoded.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType_0  \
# 0         Lvl    AllPub  ...         NaN       0      2   2008          0
# 1         Lvl    AllPub  ...         NaN       0      5   2007          0
# 2         Lvl    AllPub  ...         NaN       0      9   2008          0
# 3         Lvl    AllPub  ...         NaN       0      2   2006          0
# 4         Lvl    AllPub  ...         NaN       0     12   2008          0
#
#   SaleType_1 SaleType_2  SaleType_3  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 4. Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
df4.head(4)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# ...

# %%
df4.SaleCondition.unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
ordinal = OrdinalEncoder(categories = [['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family']])
ordinal
# Out:
# OrdinalEncoder(categories=[['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca',
#                             'Family']])

# %%
df4.Area = ordinal.fit_transform(df5[['SaleCondition']])
df4.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 5. Frequency Encoding

# %%
df5.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
frequency_encoding = df5['LotArea'].value_counts().to_dict()
frequency_encoding
# Out:
# {7200: 25,
#  9600: 24,
#  6000: 17,
#  9000: 14,
#  8400: 14,
#  10800: 14,
#  1680: 10,
#  7500: 9,
#  9100: 8,
#  8125: 8,
#  6120: 8,
#  6240: 8,
#  3182: 7,
#  7800: 6,
#  8450: 6,
#  4435: 5,
#  10140: 5,
#  10000: 5,
#  5000: 5,
#  4500: 5,
#  9750: 5,
#  5400: 5,
#  10400: 5,
#  9900: 4,
#  13125: 4,
#  6600: 4,
#  8800: 4,
#  8640: 4,
#  9375: 4,
#  7000: 4,
#  8750: 4,
#  7018: 4,
#  11250: 4,
#  8520: 4,
#  10625: 4,
#  8544: 4,
#  8500: 4,
#  11700: 4,
#  9120: 3,
#  8000: 3,
#  11600: 3,
#  9084: 3,
#  6762: 3,
#  7750: 3,
#  12090: 3,
#  8012: 3,
#  3675: 3,
#  13891: 3,
#  10200: 3,
#  8777: 3,
#  14115: 3,
#  10440: 3,
#  2280: 3,
#  2117: 3,
#  2522: 3,
#  10500: 3,
#  9920: 3,
#  9200: 3,
#  8712: 3,
#  4426: 3,
#  7875: 3,
#  11500: 3,
#  9400: 2,
#  1533: 2,
#  9760: 2,
#  15611: 2,
#  9819: 2,
#  5500: 2,
#  11340: 2,
#  14000: 2,
#  13500: 2,
#  12342: 2,
#  14803: 2,
#  12000: 2,
#  9060: 2,
#  9786: 2,
#  8773: 2,
#  10410: 2,
#  7917: 2,
#  10125: 2,
# ...

# %%
df['Area_Frequency_Encoded'] = df['LotArea'].map(frequency_encoding)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  Area_Frequency_Encoded
# ...

# %% [markdown]
# # 6. Mean Encoding

# %%
df6.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mean_encoded_area = df6.groupby('SaleCondition')['SalePrice'].mean().to_dict()
mean_encoded_area
# Out:
# {'Abnorml': 146526.62376237623,
#  'AdjLand': 104125.0,
#  'Alloca': 167377.41666666666,
#  'Family': 149600.0,
#  'Normal': 175202.21953255427,
#  'Partial': 272291.752}

# %%
unique_sale = df6['SaleCondition'].unique()
unique_sale
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
df7['SaleCondition'] = df6['SaleCondition'].map(mean_encoded_area)
df7.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...
